# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
mpl.rcParams['axes.unicode_minus'] = False
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Malgun' in f.name]
plt.rcParams['font.family'] = 'Malgun Gothic'

import seaborn as sns

# %%
df = pd.read_csv('data/골프장_결측치대체.csv')

# %%
df
# Out:
#           골프장명 골프장지역명  대중제,회원제  홀수      사용일자    사용시간  성별코드    나이 도민,비도민   실력  \
# 0         중문GC   서귀포권      대중제  18  20210531   83537     1  40.0     도민  144
# 1       더클래식CC    동부권      대중제  18  20210706  133106     2  40.0     도민  미기재
# 2       더클래식CC    동부권      대중제  18  20210706  134812     2  40.0     도민  미기재
# 3         제주CC   제주시권      대중제  18  20210706  134846     2  40.0     도민  미기재
# 4      스프링데일CC    동부권      대중제  18  20210706  135804     1  40.0     도민  미기재
# ...        ...    ...      ...  ..       ...     ...   ...   ...    ...  ...
# 45321    해비치CC    동부권  회원제+대중제  36  20201231    1227     0   미기재     도민  미기재
# 45322     라온GC    서부권      대중제  27  20201226    1132     0   미기재     도민  미기재
# 45323   더클래식CC    동부권      대중제  18  20210127     743     2   미기재     도민  미기재
# 45324    아덴힐GC    서부권      대중제  18  20201228    1215     2  40.0     도민  미기재
# 45325   더클래식CC    동부권      대중제  18  20210119     756     1  40.0     도민  미기재
#
#        골프경력 평균사용값  사용성향  판매업체명
# ...

# %%
df.groupby(df['도민,비도민']).sum()
# Out:
#              홀수          사용일자        사용시간   성별코드
# 도민,비도민
# 도민      1044765  886421366128  2347306138  39231
# 비도민       37737   29542803789    56648288   1398

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45326 entries, 0 to 45325
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   골프장명     45326 non-null  object
#  1   골프장지역명   45326 non-null  object
#  2   대중제,회원제  45326 non-null  object
#  3   홀수       45326 non-null  int64
#  4   사용일자     45326 non-null  int64
#  5   사용시간     45326 non-null  int64
#  6   성별코드     45326 non-null  int64
#  7   나이       45326 non-null  object
#  8   도민,비도민   45326 non-null  object
#  9   실력       45326 non-null  object
#  10  골프경력     45326 non-null  object
#  11  평균사용값    45326 non-null  object
#  12  사용성향     45326 non-null  object
#  13  판매업체명    45326 non-null  object
# dtypes: int64(4), object(10)
# memory usage: 4.8+ MB

# %%
df
# Out:
#           골프장명 골프장지역명  대중제,회원제  홀수      사용일자    사용시간  성별코드    나이 도민,비도민   실력  \
# 0         중문GC   서귀포권      대중제  18  20210531   83537     1  40.0     도민  144
# 1       더클래식CC    동부권      대중제  18  20210706  133106     2  40.0     도민  미기재
# 2       더클래식CC    동부권      대중제  18  20210706  134812     2  40.0     도민  미기재
# 3         제주CC   제주시권      대중제  18  20210706  134846     2  40.0     도민  미기재
# 4      스프링데일CC    동부권      대중제  18  20210706  135804     1  40.0     도민  미기재
# ...        ...    ...      ...  ..       ...     ...   ...   ...    ...  ...
# 45321    해비치CC    동부권  회원제+대중제  36  20201231    1227     0   미기재     도민  미기재
# 45322     라온GC    서부권      대중제  27  20201226    1132     0   미기재     도민  미기재
# 45323   더클래식CC    동부권      대중제  18  20210127     743     2   미기재     도민  미기재
# 45324    아덴힐GC    서부권      대중제  18  20201228    1215     2  40.0     도민  미기재
# 45325   더클래식CC    동부권      대중제  18  20210119     756     1  40.0     도민  미기재
#
#        골프경력 평균사용값  사용성향  판매업체명
# ...

# %%
df
# Out:
#           골프장명 골프장지역명  대중제,회원제  홀수      사용일자    사용시간  성별코드    나이 도민,비도민   실력  \
# 0         중문GC   서귀포권      대중제  18  20210531   83537     1  40.0     도민  144
# 1       더클래식CC    동부권      대중제  18  20210706  133106     2  40.0     도민  미기재
# 2       더클래식CC    동부권      대중제  18  20210706  134812     2  40.0     도민  미기재
# 3         제주CC   제주시권      대중제  18  20210706  134846     2  40.0     도민  미기재
# 4      스프링데일CC    동부권      대중제  18  20210706  135804     1  40.0     도민  미기재
# ...        ...    ...      ...  ..       ...     ...   ...   ...    ...  ...
# 45321    해비치CC    동부권  회원제+대중제  36  20201231    1227     0   미기재     도민  미기재
# 45322     라온GC    서부권      대중제  27  20201226    1132     0   미기재     도민  미기재
# 45323   더클래식CC    동부권      대중제  18  20210127     743     2   미기재     도민  미기재
# 45324    아덴힐GC    서부권      대중제  18  20201228    1215     2  40.0     도민  미기재
# 45325   더클래식CC    동부권      대중제  18  20210119     756     1  40.0     도민  미기재
#
#        골프경력 평균사용값  사용성향  판매업체명
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45326 entries, 0 to 45325
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   골프장명     45326 non-null  object
#  1   골프장지역명   45326 non-null  object
#  2   대중제,회원제  45326 non-null  object
#  3   홀수       45326 non-null  int64
#  4   사용일자     45326 non-null  int64
#  5   사용시간     45326 non-null  int64
#  6   성별코드     45326 non-null  int64
#  7   나이       45326 non-null  object
#  8   도민,비도민   45326 non-null  object
#  9   실력       45326 non-null  object
#  10  골프경력     45326 non-null  object
#  11  평균사용값    45326 non-null  object
#  12  사용성향     45326 non-null  object
#  13  판매업체명    45326 non-null  object
# dtypes: int64(4), object(10)
# memory usage: 4.8+ MB

# %%
df[type==np.int64] = df[type==np.int64].apply(lambda x : str(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45326 entries, 0 to 45325
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   골프장명     45326 non-null  object
#  1   골프장지역명   45326 non-null  object
#  2   대중제,회원제  45326 non-null  object
#  3   홀수       45326 non-null  int64
#  4   사용일자     45326 non-null  int64
#  5   사용시간     45326 non-null  int64
#  6   성별코드     45326 non-null  int64
#  7   나이       45326 non-null  object
#  8   도민,비도민   45326 non-null  object
#  9   실력       45326 non-null  object
#  10  골프경력     45326 non-null  object
#  11  평균사용값    45326 non-null  object
#  12  사용성향     45326 non-null  object
#  13  판매업체명    45326 non-null  object
#  14  False    45326 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 5.2+ MB

# %%
df.info
# Out:
#           골프장명 골프장지역명  대중제,회원제  홀수      사용일자    사용시간  성별코드    나이 도민,비도민   실력  \
# 0         중문GC   서귀포권      대중제  18  20210531   83537     1  40.0     도민  144
# 1       더클래식CC    동부권      대중제  18  20210706  133106     2  40.0     도민  미기재
# 2       더클래식CC    동부권      대중제  18  20210706  134812     2  40.0     도민  미기재
# 3         제주CC   제주시권      대중제  18  20210706  134846     2  40.0     도민  미기재
# 4      스프링데일CC    동부권      대중제  18  20210706  135804     1  40.0     도민  미기재
# ...        ...    ...      ...  ..       ...     ...   ...   ...    ...  ...
# 45321    해비치CC    동부권  회원제+대중제  36  20201231    1227     0   미기재     도민  미기재
# 45322     라온GC    서부권      대중제  27  20201226    1132     0   미기재     도민  미기재
# 45323   더클래식CC    동부권      대중제  18  20210127     743     2   미기재     도민  미기재
# 45324    아덴힐GC    서부권      대중제  18  20201228    1215     2  40.0     도민  미기재
# 45325   더클래식CC    동부권      대중제  18  20210119     756     1  40.0     도민  미기재
#
#        골프경력 평균사용값  사용성향  판매업체명 False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45326 entries, 0 to 45325
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   골프장명     45326 non-null  object
#  1   골프장지역명   45326 non-null  object
#  2   대중제,회원제  45326 non-null  object
#  3   홀수       45326 non-null  object
#  4   사용일자     45326 non-null  object
#  5   사용시간     45326 non-null  object
#  6   성별코드     45326 non-null  object
#  7   나이       45326 non-null  object
#  8   도민,비도민   45326 non-null  object
#  9   실력       45326 non-null  object
#  10  골프경력     45326 non-null  object
#  11  평균사용값    45326 non-null  object
#  12  사용성향     45326 non-null  object
#  13  판매업체명    45326 non-null  object
# dtypes: object(14)
# memory usage: 4.8+ MB

# %%
df.성별코드 = df.성별코드.apply(lambda x : str(x) if type(x) == int else x)

# %%
type(df.성별코드[0])
# Out:
# str

# %%
df.groupby([df.골프장명[df.골프장명=='중문GC'],df.나이]).골프장명.count()
# Out:
# 골프장명  나이
# 중문GC  10.0      6
#       20.0     60
#       30.0    138
#       40.0    409
#       50.0    136
#       60.0     30
#       미기재     348
# Name: 골프장명, dtype: int64

# %%
df.groupby([df.골프장명,df.나이]).count().plot.bar()
# Out:
# <AxesSubplot:xlabel='골프장명,나이'>

# %%
df.groupby(df.성별코드).count()
# Out:
#        골프장명  골프장지역명  대중제,회원제     홀수   사용일자   사용시간     나이  도민,비도민     실력  \
# 성별코드
# 0     13016   13016    13016  13016  13016  13016  13016   13016  13016
# 1     23991   23991    23991  23991  23991  23991  23991   23991  23991
# 2      8319    8319     8319   8319   8319   8319   8319    8319   8319
#
#        골프경력  평균사용값   사용성향  판매업체명
# 성별코드
# 0     13016  13016  13016  13016
# 1     23991  23991  23991  23991
# 2      8319   8319   8319   8319

# %%
df.성별코드.value_counts()
# Out:
# 1    23991
# 0    13016
# 2     8319
# Name: 성별코드, dtype: int64

# %%
explode = [0.05, 0.05, 0.05, 0.05]
colors = ['#ff9999', '#ffc000', '#8fd9b6']
df.groupby(df.성별코드).골프장명.count().plot.pie( autopct='%.1f%%', startangle=90, counterclock=False, shadow=True, colors=colors)
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\src\\anaconda3\\envs\\tensorflow\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
df.성별코드 == df.성별코드.apply(lambda x: )
