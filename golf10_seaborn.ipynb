# %% [markdown]
# # Seaborn 을 이용한 골프장 데이터 시각화

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import copy
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
df = pd.read_csv('골프장데이터ver_date_0223.csv')
# Out:
# C:\src\anaconda3\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (6,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.columns
# Out:
# Index(['골프장명', '골프장지역명', '골프장멤버십값', '골프장유형값', '사용일자', '사용시간값', '사용유형명',
#        '거주자금액', '비거주자금액', '결제수단명', '총인원수', '거주자인원수', '비거주자인원수', '예약일자', '예약시간',
#        '판매업체명', '예약자성별코드', '예약자연령대코드', '예약자거주지값', '예약자평균값', '예약자골프경력값',
#        '예약자평균사용값', '예약자사용성향값', '통화일자', '통화시간', '해당년도', '통화,사용일자년도', '계절', '월',
#        '시간대', '사용일월', '통화사용월일'],
#       dtype='object')

# %%
df
# Out:
#          골프장명 골프장지역명  골프장멤버십값  골프장유형값      사용일자   사용시간값 사용유형명     거주자금액  \
# 0       해비치CC    동부권  회원제+대중제      36  202101.0   815.0   SKY  170000.0
# 1       아덴힐GC    서부권      대중제      18  202101.0   809.0   왕이메   90000.0
# 2       아덴힐GC    서부권      대중제      18  202101.0   823.0   왕이메   90000.0
# 3       아덴힐GC    서부권      대중제      18  202101.0   809.0   왕이메   90000.0
# 4       아덴힐GC    서부권      대중제      18  202102.0  1121.0    새별  110000.0
# ...       ...    ...      ...     ...       ...     ...   ...       ...
# 45321    제주CC   제주시권      대중제      18       NaN     NaN   NaN       NaN
# 45322  더클래식CC    동부권      대중제      18       NaN     NaN   NaN       NaN
# 45323  더클래식CC    동부권      대중제      18       NaN     NaN   NaN       NaN
# 45324  더클래식CC    동부권      대중제      18       NaN     NaN   NaN       NaN
# 45325    제주CC   제주시권      대중제      18       NaN     NaN   NaN       NaN
#
#          비거주자금액 결제수단명  ...  예약자사용성향값      통화일자      통화시간    해당년도  통화,사용일자년도  \
# 0      170000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 1      135000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 2      135000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 3      135000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 4      145000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# ...         ...   ...  ...       ...       ...       ...     ...        ...
# 45321       NaN   NaN  ...       NaN  202106.0  103439.0     NaN       2021
# 45322       NaN   NaN  ...     골프초년생  202106.0  104114.0     NaN       2021
# 45323       NaN   NaN  ...     골프초년생  202106.0  104132.0     NaN       2021
# 45324       NaN   NaN  ...     골프초년생  202106.0  104224.0     NaN       2021
# 45325       NaN   NaN  ...     골프초년생  202106.0  104250.0     NaN       2021
#
#        계절   월  시간대        사용일월      통화사용월일
# 0      겨울  1월   아침  20210120.0  20210531.0
# 1      겨울  1월   아침  20210121.0  20210706.0
# 2      겨울  1월   아침  20210126.0  20210706.0
# 3      겨울  1월   아침  20210128.0  20210706.0
# 4      겨울  2월   아침  20210208.0  20210706.0
# ...    ..  ..  ...         ...         ...
# 45321  여름  6월  미분류         NaN         NaN
# 45322  여름  6월  미분류         NaN         NaN
# 45323  여름  6월  미분류         NaN         NaN
# 45324  여름  6월  미분류         NaN         NaN
# 45325  여름  6월  미분류         NaN         NaN
#
# [45326 rows x 32 columns]

# %%
plt.figure(figsize=(24,24))
sns.FacetGrid(df, col = '계절', row = '골프장멤버십값').map(sns.distplot, '거주자금액')
plt.show()
# Out:
# C:\Users\alsdn\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\alsdn\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\alsdn\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\alsdn\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\alsdn\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\alsdn\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\alsdn\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\alsdn\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\alsdn\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\alsdn\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\alsdn\AppData\Roaming\Python\Python37\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df
# Out:
#          골프장명 골프장지역명  골프장멤버십값  골프장유형값      사용일자   사용시간값 사용유형명     거주자금액  \
# 0       해비치CC    동부권  회원제+대중제      36  202101.0   815.0   SKY  170000.0
# 1       아덴힐GC    서부권      대중제      18  202101.0   809.0   왕이메   90000.0
# 2       아덴힐GC    서부권      대중제      18  202101.0   823.0   왕이메   90000.0
# 3       아덴힐GC    서부권      대중제      18  202101.0   809.0   왕이메   90000.0
# 4       아덴힐GC    서부권      대중제      18  202102.0  1121.0    새별  110000.0
# ...       ...    ...      ...     ...       ...     ...   ...       ...
# 45321    제주CC   제주시권      대중제      18       NaN     NaN   NaN       NaN
# 45322  더클래식CC    동부권      대중제      18       NaN     NaN   NaN       NaN
# 45323  더클래식CC    동부권      대중제      18       NaN     NaN   NaN       NaN
# 45324  더클래식CC    동부권      대중제      18       NaN     NaN   NaN       NaN
# 45325    제주CC   제주시권      대중제      18       NaN     NaN   NaN       NaN
#
#          비거주자금액 결제수단명  ...  예약자사용성향값      통화일자      통화시간    해당년도  통화,사용일자년도  \
# 0      170000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 1      135000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 2      135000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 3      135000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 4      145000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# ...         ...   ...  ...       ...       ...       ...     ...        ...
# 45321       NaN   NaN  ...       NaN  202106.0  103439.0     NaN       2021
# 45322       NaN   NaN  ...     골프초년생  202106.0  104114.0     NaN       2021
# 45323       NaN   NaN  ...     골프초년생  202106.0  104132.0     NaN       2021
# 45324       NaN   NaN  ...     골프초년생  202106.0  104224.0     NaN       2021
# 45325       NaN   NaN  ...     골프초년생  202106.0  104250.0     NaN       2021
#
#        계절   월  시간대        사용일월      통화사용월일
# 0      겨울  1월   아침  20210120.0  20210531.0
# 1      겨울  1월   아침  20210121.0  20210706.0
# 2      겨울  1월   아침  20210126.0  20210706.0
# 3      겨울  1월   아침  20210128.0  20210706.0
# 4      겨울  2월   아침  20210208.0  20210706.0
# ...    ..  ..  ...         ...         ...
# 45321  여름  6월  미분류         NaN         NaN
# 45322  여름  6월  미분류         NaN         NaN
# 45323  여름  6월  미분류         NaN         NaN
# 45324  여름  6월  미분류         NaN         NaN
# 45325  여름  6월  미분류         NaN         NaN
#
# [45326 rows x 32 columns]

# %%
df.groupby([df.골프장명,df.골프장지역명])[['골프장멤버십값']].count().plot.barh()
# Out:
# <AxesSubplot:ylabel='골프장명,골프장지역명'>

# %%
df.골프장지역명.value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
sns.set_theme(style="ticks")
sns.pairplot(df.groupby(df.골프장지역명)[['골프장멤버십값']].count(),hue='골프장명')

# %%
sns.distplot(df.groupby([df.골프장명,df.골프장지역명])[['골프장멤버십값'].count())
# Out:
#   File "C:\Users\alsdn\AppData\Local\Temp\ipykernel_23020\2492981426.py", line 1
#     sns.distplot(df.groupby([df.골프장명,df.골프장지역명])[['골프장멤버십값'].count())
#                                                                     ^
# SyntaxError: invalid syntax

# %%
df.groupby([df.골프장명,df.골프장지역명])[['골프장멤버십값']].count().plot.barh()

# %%
df.columns
# Out:
# Index(['골프장명', '골프장지역명', '골프장멤버십값', '골프장유형값', '사용일자', '사용시간값', '사용유형명',
#        '거주자금액', '비거주자금액', '결제수단명', '총인원수', '거주자인원수', '비거주자인원수', '예약일자', '예약시간',
#        '판매업체명', '예약자성별코드', '예약자연령대코드', '예약자거주지값', '예약자평균값', '예약자골프경력값',
#        '예약자평균사용값', '예약자사용성향값', '통화일자', '통화시간', '해당년도', '통화,사용일자년도', '계절', '월',
#        '시간대', '사용일월', '통화사용월일'],
#       dtype='object')

# %%
sns.histplot(x=df['계절'])
# Out:
# <AxesSubplot:xlabel='계절', ylabel='Count'>

# %%
df
# Out:
#          골프장명 골프장지역명  골프장멤버십값  골프장유형값      사용일자   사용시간값 사용유형명     거주자금액  \
# 0       해비치CC    동부권  회원제+대중제      36  202101.0   815.0   SKY  170000.0
# 1       아덴힐GC    서부권      대중제      18  202101.0   809.0   왕이메   90000.0
# 2       아덴힐GC    서부권      대중제      18  202101.0   823.0   왕이메   90000.0
# 3       아덴힐GC    서부권      대중제      18  202101.0   809.0   왕이메   90000.0
# 4       아덴힐GC    서부권      대중제      18  202102.0  1121.0    새별  110000.0
# ...       ...    ...      ...     ...       ...     ...   ...       ...
# 45321    제주CC   제주시권      대중제      18       NaN     NaN   NaN       NaN
# 45322  더클래식CC    동부권      대중제      18       NaN     NaN   NaN       NaN
# 45323  더클래식CC    동부권      대중제      18       NaN     NaN   NaN       NaN
# 45324  더클래식CC    동부권      대중제      18       NaN     NaN   NaN       NaN
# 45325    제주CC   제주시권      대중제      18       NaN     NaN   NaN       NaN
#
#          비거주자금액 결제수단명  ...  예약자사용성향값      통화일자      통화시간    해당년도  통화,사용일자년도  \
# 0      170000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 1      135000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 2      135000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 3      135000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 4      145000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# ...         ...   ...  ...       ...       ...       ...     ...        ...
# 45321       NaN   NaN  ...       NaN  202106.0  103439.0     NaN       2021
# 45322       NaN   NaN  ...     골프초년생  202106.0  104114.0     NaN       2021
# 45323       NaN   NaN  ...     골프초년생  202106.0  104132.0     NaN       2021
# 45324       NaN   NaN  ...     골프초년생  202106.0  104224.0     NaN       2021
# 45325       NaN   NaN  ...     골프초년생  202106.0  104250.0     NaN       2021
#
#        계절   월  시간대        사용일월      통화사용월일
# 0      겨울  1월   아침  20210120.0  20210531.0
# 1      겨울  1월   아침  20210121.0  20210706.0
# 2      겨울  1월   아침  20210126.0  20210706.0
# 3      겨울  1월   아침  20210128.0  20210706.0
# 4      겨울  2월   아침  20210208.0  20210706.0
# ...    ..  ..  ...         ...         ...
# 45321  여름  6월  미분류         NaN         NaN
# 45322  여름  6월  미분류         NaN         NaN
# 45323  여름  6월  미분류         NaN         NaN
# 45324  여름  6월  미분류         NaN         NaN
# 45325  여름  6월  미분류         NaN         NaN
#
# [45326 rows x 32 columns]

# %%
sns.jointplot(x=df['계절'], y=df['월'], kind = 'scatter')

# %%
df
# Out:
#          골프장명 골프장지역명  골프장멤버십값  골프장유형값      사용일자   사용시간값 사용유형명     거주자금액  \
# 0       해비치CC    동부권  회원제+대중제      36  202101.0   815.0   SKY  170000.0
# 1       아덴힐GC    서부권      대중제      18  202101.0   809.0   왕이메   90000.0
# 2       아덴힐GC    서부권      대중제      18  202101.0   823.0   왕이메   90000.0
# 3       아덴힐GC    서부권      대중제      18  202101.0   809.0   왕이메   90000.0
# 4       아덴힐GC    서부권      대중제      18  202102.0  1121.0    새별  110000.0
# ...       ...    ...      ...     ...       ...     ...   ...       ...
# 45321    제주CC   제주시권      대중제      18       NaN     NaN   NaN       NaN
# 45322  더클래식CC    동부권      대중제      18       NaN     NaN   NaN       NaN
# 45323  더클래식CC    동부권      대중제      18       NaN     NaN   NaN       NaN
# 45324  더클래식CC    동부권      대중제      18       NaN     NaN   NaN       NaN
# 45325    제주CC   제주시권      대중제      18       NaN     NaN   NaN       NaN
#
#          비거주자금액 결제수단명  ...  예약자사용성향값      통화일자      통화시간    해당년도  통화,사용일자년도  \
# 0      170000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 1      135000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 2      135000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 3      135000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# 4      145000.0  현장결제  ...       NaN       NaN       NaN  2021.0       2021
# ...         ...   ...  ...       ...       ...       ...     ...        ...
# 45321       NaN   NaN  ...       NaN  202106.0  103439.0     NaN       2021
# 45322       NaN   NaN  ...     골프초년생  202106.0  104114.0     NaN       2021
# 45323       NaN   NaN  ...     골프초년생  202106.0  104132.0     NaN       2021
# 45324       NaN   NaN  ...     골프초년생  202106.0  104224.0     NaN       2021
# 45325       NaN   NaN  ...     골프초년생  202106.0  104250.0     NaN       2021
#
#        계절   월  시간대        사용일월      통화사용월일
# 0      겨울  1월   아침  20210120.0  20210531.0
# 1      겨울  1월   아침  20210121.0  20210706.0
# 2      겨울  1월   아침  20210126.0  20210706.0
# 3      겨울  1월   아침  20210128.0  20210706.0
# 4      겨울  2월   아침  20210208.0  20210706.0
# ...    ..  ..  ...         ...         ...
# 45321  여름  6월  미분류         NaN         NaN
# 45322  여름  6월  미분류         NaN         NaN
# 45323  여름  6월  미분류         NaN         NaN
# 45324  여름  6월  미분류         NaN         NaN
# 45325  여름  6월  미분류         NaN         NaN
#
# [45326 rows x 32 columns]

# %%
sns.barplot(x = df['sex'], y = df['tip'])

# %%
sns.countplot(x=df[df['골프장명'].apply(lambda x: True if ( x in ['해비치CC','아덴힐GC']) else False)].골프장명)
# Out:
# <AxesSubplot:xlabel='골프장명', ylabel='count'>

# %%
df['골프장명'].value_counts()[:5].keys()
# Out:
# Index(['라온GC', '더클래식CC', '아덴힐GC', '해비치CC', '제주CC'], dtype='object')

# %%
sns.countplot(x=df[df['골프장명'].apply(lambda x: True if ( x in df['골프장명'].value_counts()[:-3].keys()) else False)].골프장명)
# Out:
# <AxesSubplot:xlabel='골프장명', ylabel='count'>

# %%
plt.figure(figsize = (25,8))
sns.countplot(x=df['골프장명'][])
plt.legend()
plt.show()
# Out:
#   File "C:\Users\alsdn\AppData\Local\Temp\ipykernel_23020\3418069258.py", line 2
#     sns.countplot(x=df['골프장명'][])
#                                ^
# SyntaxError: invalid syntax

# %%
df['골프장명'].value_counts()[:-3].plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df.골프장명[df['골프장명'].value_counts()])
# Out:
# <AxesSubplot:xlabel='골프장명', ylabel='count'>
