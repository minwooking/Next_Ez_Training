# %% [markdown]
# # Seaborn 을 이용한 골프장 데이터 시각화

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import copy
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
df = pd.read_csv('골프장데이터ver_date_0223.csv')
# Out:
# C:\Users\alsdn\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (6,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.columns
# Out:
# Index(['골프장명', '골프장지역명', '골프장멤버십값', '골프장유형값', '사용일자', '사용시간값', '사용유형명',
#        '거주자금액', '비거주자금액', '결제수단명', '총인원수', '거주자인원수', '비거주자인원수', '예약일자', '예약시간',
#        '판매업체명', '예약자성별코드', '예약자연령대코드', '예약자거주지값', '예약자평균값', '예약자골프경력값',
#        '예약자평균사용값', '예약자사용성향값', '통화일자', '통화시간', '해당년도', '통화,사용일자년도', '계절', '월',
#        '시간대', '사용일월', '통화사용월일'],
#       dtype='object')

# %%
df.head(3)
# Out:
#     골프장명 골프장지역명  골프장멤버십값  골프장유형값      사용일자  사용시간값 사용유형명     거주자금액    비거주자금액  \
# 0  해비치CC    동부권  회원제+대중제      36  202101.0  815.0   SKY  170000.0  170000.0
# 1  아덴힐GC    서부권      대중제      18  202101.0  809.0   왕이메   90000.0  135000.0
# 2  아덴힐GC    서부권      대중제      18  202101.0  823.0   왕이메   90000.0  135000.0
#
#   결제수단명  ...  예약자사용성향값  통화일자  통화시간    해당년도  통화,사용일자년도  계절   월  시간대  \
# 0  현장결제  ...       NaN   NaN   NaN  2021.0       2021  겨울  1월   아침
# 1  현장결제  ...       NaN   NaN   NaN  2021.0       2021  겨울  1월   아침
# 2  현장결제  ...       NaN   NaN   NaN  2021.0       2021  겨울  1월   아침
#
#          사용일월      통화사용월일
# 0  20210120.0  20210531.0
# 1  20210121.0  20210706.0
# 2  20210126.0  20210706.0
#
# [3 rows x 32 columns]

# %%
plt.figure(figsize=(24,24))
sns.FacetGrid(df, col = '계절', row = '골프장멤버십값').map(sns.distplot, '거주자금액')
plt.show()
# Out:
# C:\Users\alsdn\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\alsdn\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
df.head(3)

# %%
df.groupby([df.골프장명,df.골프장지역명])[['골프장멤버십값']].count().plot.barh(figsize=(20,20),hue='골프장명')

# %%
df.골프장지역명.value_counts().plot.barh()

# %%
sns.set_theme(style="ticks")
sns.pairplot(df.groupby(df.골프장지역명)[['골프장멤버십값']].count(),hue='골프장명')

# %%
sns.distplot(df.groupby([df.골프장명,df.골프장지역명])[['골프장멤버십값'].count())
# Out:
#   File "C:\Users\alsdn\AppData\Local\Temp/ipykernel_20208/695285404.py", line 1
#     sns.distplot(df.groupby([df.골프장명,df.골프장지역명])[['골프장멤버십값'].count())
#                                                                     ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
df.groupby([df.골프장명,df.골프장지역명])[['골프장멤버십값']].count().plot.barh()
# Out:
# <AxesSubplot:ylabel='골프장명,골프장지역명'>
# C:\Users\alsdn\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\alsdn\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\alsdn\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54596 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\alsdn\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 46300 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\alsdn\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
df.columns
# Out:
# Index(['골프장명', '골프장지역명', '골프장멤버십값', '골프장유형값', '사용일자', '사용시간값', '사용유형명',
#        '거주자금액', '비거주자금액', '결제수단명', '총인원수', '거주자인원수', '비거주자인원수', '예약일자', '예약시간',
#        '판매업체명', '예약자성별코드', '예약자연령대코드', '예약자거주지값', '예약자평균값', '예약자골프경력값',
#        '예약자평균사용값', '예약자사용성향값', '통화일자', '통화시간', '해당년도', '통화,사용일자년도', '계절', '월',
#        '시간대', '사용일월', '통화사용월일'],
#       dtype='object')

# %%
sns.set(rc = {'figure.figsize':(15,8)})
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.histplot(x=df['계절'],)
# Out:
# <AxesSubplot:xlabel='계절', ylabel='Count'>

# %%
df.head(3)

# %%
sns.jointplot(x=df['계절'], y=df['월'], kind = 'scatter')

# %%
df.head(3)

# %%
sns.set(rc = {'figure.figsize':(15,8)})
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x=df[df['골프장명'].apply(lambda x: True if ( x in ['해비치CC','아덴힐GC']) else False)].골프장명)
# Out:
# <AxesSubplot:xlabel='골프장명', ylabel='count'>

# %%
df['골프장명'].value_counts()[:5].keys() # Top 5
# Out:
# Index(['라온GC', '더클래식CC', '아덴힐GC', '해비치CC', '제주CC'], dtype='object')

# %%
## 탑 5 표시
sns.set(rc = {'figure.figsize':(15,8)})
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.countplot(x=df[df['골프장명'].apply(lambda x: True if ( x in df['골프장명'].value_counts()[:5].keys()) else False)].골프장명)
# Out:
# <AxesSubplot:xlabel='골프장명', ylabel='count'>

# %%
## 적은사람 3명 없애기 
# plt.rcParams['figure.figsize'] = 15,8
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.figure(figsize = (30,16))
sns.countplot(x=df[df['골프장명'].apply(lambda x: True if ( x in df['골프장명'].value_counts()[:-3].keys()) else False)].골프장명)
# Out:
# <AxesSubplot:xlabel='골프장명', ylabel='count'>

# %%
plt.figure(figsize = (25,8))
sns.countplot(x=df['골프장명'][])
plt.legend()
plt.show()
# Out:
#   File "C:\Users\alsdn\AppData\Local\Temp/ipykernel_20208/1268654751.py", line 2
#     sns.countplot(x=df['골프장명'][])
#                                ^
# SyntaxError: invalid syntax

# %%
plt.Figure(figsize=20,20)
df['골프장명'].value_counts()[:-3].plot.bar()
# Out:
#   File "C:\Users\alsdn\AppData\Local\Temp/ipykernel_20208/1409216977.py", line 1
#     plt.Figure(figsize=20,20)
#                             ^
# SyntaxError: positional argument follows keyword argument

# %%
df['골프장명'].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
sns.countplot(df.골프장명[df['골프장명'].value_counts()])
# Out:
# C:\Users\alsdn\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='골프장명', ylabel='count'>

# %%
df.head(3)

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()

# %%
keras.__version__

# %%
tf.__version__

# %%
sns.distplot(df['골프장명'], kde=True, rug=True)
plt.title("Iris 데이터 중, 꽃잎의 길이에 대한 Dist Plot")
plt.show()

# %%
sns.displot
# Out:
# <function seaborn.distributions.displot(data=None, *, x=None, y=None, hue=None, row=None, col=None, weights=None, kind='hist', rug=False, rug_kws=None, log_scale=None, legend=True, palette=None, hue_order=None, hue_norm=None, color=None, col_wrap=None, row_order=None, col_order=None, height=5, aspect=1, facet_kws=None, **kwargs)>

# %%
df.head(3)
# Out:
#     골프장명 골프장지역명  골프장멤버십값  골프장유형값      사용일자  사용시간값 사용유형명     거주자금액    비거주자금액  \
# 0  해비치CC    동부권  회원제+대중제      36  202101.0  815.0   SKY  170000.0  170000.0
# 1  아덴힐GC    서부권      대중제      18  202101.0  809.0   왕이메   90000.0  135000.0
# 2  아덴힐GC    서부권      대중제      18  202101.0  823.0   왕이메   90000.0  135000.0
#
#   결제수단명  ...  예약자사용성향값  통화일자  통화시간    해당년도  통화,사용일자년도  계절   월  시간대  \
# 0  현장결제  ...       NaN   NaN   NaN  2021.0       2021  겨울  1월   아침
# 1  현장결제  ...       NaN   NaN   NaN  2021.0       2021  겨울  1월   아침
# 2  현장결제  ...       NaN   NaN   NaN  2021.0       2021  겨울  1월   아침
#
#          사용일월      통화사용월일
# 0  20210120.0  20210531.0
# 1  20210121.0  20210706.0
# 2  20210126.0  20210706.0
#
# [3 rows x 32 columns]

# %%
why commit 이 안되냐

# %%
sns.set(rc = {'figure.figsize':(50
                                ,20)})
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.displot(df[df.시간대 != '미분류'], y="시간대", hue="골프장명")

# %%
sns.set(rc = {'figure.figsize':(50,20)})
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.displot(df[df.시간대 != '미분류'], x="골프장지역명", hue="시간대")

# %%
sns.set(rc = {'figure.figsize':(25,25)})
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.displot(data=df[df.시간대 != '미분류'], x="시간대",col='골프장지역명',hue='시간대')

# %%
sns.set(rc = {'figure.figsize':(25,25)})
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.displot(data=df, x="시간대",col='골프장지역명',hue='시간대')

# %%
plt.figure(figsize=(25,25))
df.groupby(df.골프장명).골프장지역명.count().plot.pie(fontsize=20,autopct='%.1f%%')
# Out:
# <AxesSubplot:ylabel='골프장지역명'>

# %%
sns.heatmap(df.corr(), annot = True, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df,hue='골프장지역명')

# %%
df.columns
# Out:
# Index(['골프장명', '골프장지역명', '골프장멤버십값', '골프장유형값', '사용일자', '사용시간값', '사용유형명',
#        '거주자금액', '비거주자금액', '결제수단명', '총인원수', '거주자인원수', '비거주자인원수', '예약일자', '예약시간',
#        '판매업체명', '예약자성별코드', '예약자연령대코드', '예약자거주지값', '예약자평균값', '예약자골프경력값',
#        '예약자평균사용값', '예약자사용성향값', '통화일자', '통화시간', '해당년도', '통화,사용일자년도', '계절', '월',
#        '시간대', '사용일월', '통화사용월일'],
#       dtype='object')

# %%
df.예약자연령대코드.value_counts().plot.bar(color='#81AB7D')
plt.xlabel('나이')
plt.ylabel('명수')
# Out:
# Text(0, 0.5, '명수')

# %%
pd.DataFrame(df.예약자연령대코드.value_counts())
# Out:
#       예약자연령대코드
# 40.0     15244
# 50.0      7252
# 30.0      5432
# 60.0      1105
# 20.0       950
# 10.0        95
# 70.0        20

# %%
pd.DataFrame(df.시간대.value_counts())
# Out:
#        시간대
# 미분류  18796
# 아침   12200
# 새벽    9038
# 오후    4539
# 야간     753

# %%
df.판매업체명.value_counts().plot.barh(color='#81AB7D')
plt.grid()
plt.title('판매업체명')
plt.xlabel('명')
plt.ylabel('업체명')
# Out:
# Text(0, 0.5, '업체명')

# %%
df.columns
# Out:
# Index(['골프장명', '골프장지역명', '골프장멤버십값', '골프장유형값', '사용일자', '사용시간값', '사용유형명',
#        '거주자금액', '비거주자금액', '결제수단명', '총인원수', '거주자인원수', '비거주자인원수', '예약일자', '예약시간',
#        '판매업체명', '예약자성별코드', '예약자연령대코드', '예약자거주지값', '예약자평균값', '예약자골프경력값',
#        '예약자평균사용값', '예약자사용성향값', '통화일자', '통화시간', '해당년도', '통화,사용일자년도', '계절', '월',
#        '시간대', '사용일월', '통화사용월일'],
#       dtype='object')

# %%
df.예약자거주지값.value_counts()
# Out:
# 도민     43864
# 비도민     1462
# Name: 예약자거주지값, dtype: int64

# %%
df.groupby([df.예약자거주지값[df.예약자거주지값=='비도민'],df.골프장명]).골프장명.count().plot.barh(fontsize=25,color='#81AB7D')
plt.grid()
plt.title('비도민')
plt.xlabel('명')
plt.ylabel('업체명')
# Out:
# Text(0, 0.5, '업체명')

# %%
df.예약자거주지값[df.예약자거주지값=='도민'].count()
# Out:
# 43864

# %%
sns.set(rc = {'figure.figsize':(25,25)})
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.displot(data=df, x="골프장명",y='예약자거주지값',hue='골프장명')

# %%
plt.figure(figsize=(10,8))
df[df.골프장명=='해비치CC'].판매업체명.value_counts().plot.bar(color='#81AB7D',fontsize=15)
plt.grid()
plt.title('판매업체명')
plt.xlabel('업체명')
plt.ylabel('명')
# Out:
# Text(0, 0.5, '명')

# %%
sns.set(rc = {'figure.figsize':(25,25)})
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.displot(data=df[df.골프장명 == '해비치CC'], x="시간대",col='골프장명',hue='시간대')

# %%
sns.set(rc = {'figure.figsize':(25,25)})
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.displot(data=df[df.골프장명 == '해비치CC'], x="계절",col='골프장명',hue='계절')

# %%
df.columns
# Out:
# Index(['골프장명', '골프장지역명', '골프장멤버십값', '골프장유형값', '사용일자', '사용시간값', '사용유형명',
#        '거주자금액', '비거주자금액', '결제수단명', '총인원수', '거주자인원수', '비거주자인원수', '예약일자', '예약시간',
#        '판매업체명', '예약자성별코드', '예약자연령대코드', '예약자거주지값', '예약자평균값', '예약자골프경력값',
#        '예약자평균사용값', '예약자사용성향값', '통화일자', '통화시간', '해당년도', '통화,사용일자년도', '계절', '월',
#        '시간대', '사용일월', '통화사용월일'],
#       dtype='object')

# %%
sns.set(rc = {'figure.figsize':(25,25)})
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.displot(data=df[df.골프장명 == '해비치CC'], x="예약자평균사용값",col='골프장명',hue='예약자평균사용값')

# %%
df.columns
# Out:
# Index(['골프장명', '골프장지역명', '골프장멤버십값', '골프장유형값', '사용일자', '사용시간값', '사용유형명',
#        '거주자금액', '비거주자금액', '결제수단명', '총인원수', '거주자인원수', '비거주자인원수', '예약일자', '예약시간',
#        '판매업체명', '예약자성별코드', '예약자연령대코드', '예약자거주지값', '예약자평균값', '예약자골프경력값',
#        '예약자평균사용값', '예약자사용성향값', '통화일자', '통화시간', '해당년도', '통화,사용일자년도', '계절', '월',
#        '시간대', '사용일월', '통화사용월일'],
#       dtype='object')

# %%
sns.set(rc = {'figure.figsize':(25,25)})
plt.rcParams['font.family'] = 'Malgun Gothic'
sns.displot(data=df[df.골프장명 == '해비치CC'], x="예약자연령대코드",col='골프장명',hue='예약자연령대코드')

# %%
df[df.골프장명=='해비치CC'].예약자연령대코드.value_counts().plot.pie(fontsize=20,autopct='%.1f%%')
# Out:
# <AxesSubplot:ylabel='예약자연령대코드'>
