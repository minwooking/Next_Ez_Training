# %% [markdown]
# # 골프장데이터 전처리

# %% [markdown]
# ## library

# %%
import numpy as np
import pandas as pd
import copy

# %% [markdown]
# ## data

# %%
or_golf_df_phone = pd.read_csv('C:\workspace\\Next_Ez_jejudo\\data\\golflike\\섬프로_전화_2021.csv')
or_golf_df1 = pd.read_csv('C:\workspace\\Next_Ez_jejudo\\data\\golflike\\섬프로_예약_2021.csv')
or_golf_df2 = pd.read_csv('C:\workspace\\Next_Ez_jejudo\\data\\golflike\\섬프로_예약_2020.csv')
or_golf_df3 = pd.read_csv('C:\workspace\\Next_Ez_jejudo\\data\\golflike\\섬프로_예약_2020-2.csv',header=None)
or_golf_df4 = pd.read_csv('C:\\workspace\\Next_Ez_jejudo\\data\\golflike\\제주골프장_예약_2112_2202.csv',header=None,encoding='euc-kr')
or_golf_df3.columns = or_golf_df1.columns
or_golf_df4.columns = or_golf_df1.columns
or_golf_df_phone['SLE_ENTRPS_NM'] = '통화'

# %%
or_golf_df4.head(3)
# Out:
#   GLCRS_NM GLCRS_AREA_NM GLCRS_MBRSH_VALUE  GLCRS_TY_VALUE  USE_DTTM  \
# 0     제주CC         제주시내권               대중제              18  20211217
# 1     제주CC         제주시내권               대중제              18  20211217
# 2     라온GC           서부권               대중제              27  20211205
#
#    USGTM_VALUE USETY_NM  RESIDNT_AMOUNT  UNRESID_AMOUNT SETLE_MN_NM  ...  \
# 0          731       랜덤          145000          145000         선결제  ...
# 1          738       랜덤          145000          145000         선결제  ...
# 2         1214    STONE          202500          222500        현장결제  ...
#
#    RESVE_DTTM  RESVE_TIME  SLE_ENTRPS_NM  RSVCTM_SEXDSTN_CODE  \
# 0    20211201      104257       슬기로운골프생활                    X
# 1    20211201      103954       슬기로운골프생활                    1
# 2    20211201      112518           라온GC                    1
#
#    RSVCTM_AGRDE_CODE RSVCTM_RSVCTM_VALUE RSVCTM_RVRG_VALUE  \
# 0                  X                  도민                 X
# ...

# %%
or_golf_df1.head(3)
# Out:
#   GLCRS_NM GLCRS_AREA_NM GLCRS_MBRSH_VALUE  GLCRS_TY_VALUE  USE_DTTM  \
# 0    해비치CC           동부권           회원제+대중제              36  20210120
# 1    아덴힐GC           서부권               대중제              18  20210121
# 2    아덴힐GC           서부권               대중제              18  20210126
#
#    USGTM_VALUE USETY_NM  RESIDNT_AMOUNT  UNRESID_AMOUNT SETLE_MN_NM  ...  \
# 0          815      SKY          170000          170000        현장결제  ...
# 1          809      왕이메           90000          135000        현장결제  ...
# 2          823      왕이메           90000          135000        현장결제  ...
#
#    RESVE_DTTM  RESVE_TIME  SLE_ENTRPS_NM  RSVCTM_SEXDSTN_CODE  \
# 0    20210114       93902          해비치CC                    1
# 1    20210114       94001          아덴힐GC                    1
# 2    20210114       95020          아덴힐GC                    1
#
#    RSVCTM_AGRDE_CODE RSVCTM_RSVCTM_VALUE  RSVCTM_RVRG_VALUE  \
# 0               50.0                 비도민                  8
# ...

# %%
or_golf_df2.head(3)
# Out:
#   GLCRS_NM GLCRS_AREA_NM GLCRS_MBRSH_VALUE  GLCRS_TY_VALUE  USE_DTTM  \
# 0   더클래식CC           동부권               대중제              18  20200425
# 1   더클래식CC           동부권               대중제              18  20200411
# 2   엘리시안CC           서부권           회원제+대중제              36  20200416
#
#    USGTM_VALUE USETY_NM  RESIDNT_AMOUNT  UNRESID_AMOUNT SETLE_MN_NM  ...  \
# 0          844      대중제           95000               0        현장결제  ...
# 1         1301      대중제           95000               0        현장결제  ...
# 2         1333      대중제           80000               0        현장결제  ...
#
#    RESVE_DTTM  RESVE_TIME  SLE_ENTRPS_NM  RSVCTM_SEXDSTN_CODE  \
# 0    20200326      192720            섬프로                    0
# 1    20200410      114647            섬프로                    0
# 2    20200413      102231        엘리시안C.C                    2
#
#    RSVCTM_AGRDE_CODE RSVCTM_RSVCTM_VALUE  RSVCTM_RVRG_VALUE  \
# 0                NaN                  도민                NaN
# ...

# %%
or_golf_df3.head(3)
# Out:
#      GLCRS_NM GLCRS_AREA_NM GLCRS_MBRSH_VALUE  GLCRS_TY_VALUE  USE_DTTM  \
# 0     사이프러스CC           동부권           회원제+대중제              36  20200824
# 1       아덴힐GC           서부권               대중제              18  20200816
# 2  롯데스카이힐제주CC          서귀포권           회원제+대중제              36  20200802
#
#    USGTM_VALUE USETY_NM  RESIDNT_AMOUNT  UNRESID_AMOUNT SETLE_MN_NM  ...  \
# 0         1228     WEST           80000               0        현장결제  ...
# 1         1411      왕이메          125000               0        현장결제  ...
# 2          637      대중제          122500               0        현장결제  ...
#
#    RESVE_DTTM  RESVE_TIME  SLE_ENTRPS_NM  RSVCTM_SEXDSTN_CODE  \
# 0    20200810      221533        사이프러스CC                    0
# 1    20200811      111943          아덴힐GC                    0
# 2    20200728      122115    섬프로(롯데스카이힐)                    1
#
#    RSVCTM_AGRDE_CODE RSVCTM_RSVCTM_VALUE  RSVCTM_RVRG_VALUE  \
# 0                NaN                  도민                NaN
# ...

# %%
or_golf_df_phone.head(3)
# Out:
#   GLCRS_NM GLCRS_AREA_NM GLCRS_MBRSH_VALUE  GLCRS_TY_VALUE  TALKDTTM  \
# 0     중문GC          서귀포권               대중제              18  20210531
# 1   더클래식CC           동부권               대중제              18  20210706
# 2   더클래식CC           동부권               대중제              18  20210706
#
#    TALKTIME  RSVCTM_SEXDSTN_CODE  RSVCTM_AGRDE_CODE RSVCTM_RSVCTM_VALUE  \
# 0     83537                    1               40.0                  도민
# 1    133106                    2               40.0                  도민
# 2    134812                    2               40.0                  도민
#
#   RSVCTM_RVRG_VALUE RSVCTM_GOLF_CAREER_VALUE RSVCTM_AVRG_USE_VALUE  \
# 0               144                      NaN                   NaN
# 1               NaN                      NaN                   NaN
# 2               NaN                     1~3년                    2회
#
#   RSVCTM_USEINCLN_VALUE SLE_ENTRPS_NM
# 0                   NaN            통화
# 1                   NaN            통화
# ...

# %% [markdown]
# ## merge

# %%
df_merge=pd.concat([or_golf_df1,or_golf_df2],ignore_index=True)
df_merge.head(3)
# Out:
#   GLCRS_NM GLCRS_AREA_NM GLCRS_MBRSH_VALUE  GLCRS_TY_VALUE  USE_DTTM  \
# 0    해비치CC           동부권           회원제+대중제              36  20210120
# 1    아덴힐GC           서부권               대중제              18  20210121
# 2    아덴힐GC           서부권               대중제              18  20210126
#
#    USGTM_VALUE USETY_NM  RESIDNT_AMOUNT  UNRESID_AMOUNT SETLE_MN_NM  ...  \
# 0          815      SKY          170000          170000        현장결제  ...
# 1          809      왕이메           90000          135000        현장결제  ...
# 2          823      왕이메           90000          135000        현장결제  ...
#
#    RESVE_DTTM  RESVE_TIME  SLE_ENTRPS_NM  RSVCTM_SEXDSTN_CODE  \
# 0    20210114       93902          해비치CC                    1
# 1    20210114       94001          아덴힐GC                    1
# 2    20210114       95020          아덴힐GC                    1
#
#    RSVCTM_AGRDE_CODE RSVCTM_RSVCTM_VALUE  RSVCTM_RVRG_VALUE  \
# 0               50.0                 비도민                  8
# ...

# %%
df_merge2 = pd.concat([df_merge,or_golf_df3],ignore_index=True)
df_merge2.head(3)
# Out:
#   GLCRS_NM GLCRS_AREA_NM GLCRS_MBRSH_VALUE  GLCRS_TY_VALUE  USE_DTTM  \
# 0    해비치CC           동부권           회원제+대중제              36  20210120
# 1    아덴힐GC           서부권               대중제              18  20210121
# 2    아덴힐GC           서부권               대중제              18  20210126
#
#    USGTM_VALUE USETY_NM  RESIDNT_AMOUNT  UNRESID_AMOUNT SETLE_MN_NM  ...  \
# 0          815      SKY          170000          170000        현장결제  ...
# 1          809      왕이메           90000          135000        현장결제  ...
# 2          823      왕이메           90000          135000        현장결제  ...
#
#    RESVE_DTTM  RESVE_TIME  SLE_ENTRPS_NM  RSVCTM_SEXDSTN_CODE  \
# 0    20210114       93902          해비치CC                    1
# 1    20210114       94001          아덴힐GC                    1
# 2    20210114       95020          아덴힐GC                    1
#
#    RSVCTM_AGRDE_CODE RSVCTM_RSVCTM_VALUE  RSVCTM_RVRG_VALUE  \
# 0               50.0                 비도민                  8
# ...

# %%
df_merge3 = pd.concat([df_merge2,or_golf_df4],ignore_index=True)
df_merge3.head(3)
# Out:
#   GLCRS_NM GLCRS_AREA_NM GLCRS_MBRSH_VALUE  GLCRS_TY_VALUE  USE_DTTM  \
# 0    해비치CC           동부권           회원제+대중제              36  20210120
# 1    아덴힐GC           서부권               대중제              18  20210121
# 2    아덴힐GC           서부권               대중제              18  20210126
#
#    USGTM_VALUE USETY_NM  RESIDNT_AMOUNT  UNRESID_AMOUNT SETLE_MN_NM  ...  \
# 0          815      SKY          170000          170000        현장결제  ...
# 1          809      왕이메           90000          135000        현장결제  ...
# 2          823      왕이메           90000          135000        현장결제  ...
#
#    RESVE_DTTM  RESVE_TIME  SLE_ENTRPS_NM  RSVCTM_SEXDSTN_CODE  \
# 0    20210114       93902          해비치CC                    1
# 1    20210114       94001          아덴힐GC                    1
# 2    20210114       95020          아덴힐GC                    1
#
#    RSVCTM_AGRDE_CODE RSVCTM_RSVCTM_VALUE RSVCTM_RVRG_VALUE  \
# 0               50.0                 비도민                 8
# ...

# %%
df_merge3.to_csv('2203최신값.csv')

# %%
df_merge4 = pd.concat([df_merge3,or_golf_df_phone],ignore_index=True)
df_merge4.head(3)
# Out:
#   GLCRS_NM GLCRS_AREA_NM GLCRS_MBRSH_VALUE  GLCRS_TY_VALUE    USE_DTTM  \
# 0    해비치CC           동부권           회원제+대중제              36  20210120.0
# 1    아덴힐GC           서부권               대중제              18  20210121.0
# 2    아덴힐GC           서부권               대중제              18  20210126.0
#
#    USGTM_VALUE USETY_NM  RESIDNT_AMOUNT  UNRESID_AMOUNT SETLE_MN_NM  ...  \
# 0        815.0      SKY        170000.0        170000.0        현장결제  ...
# 1        809.0      왕이메         90000.0        135000.0        현장결제  ...
# 2        823.0      왕이메         90000.0        135000.0        현장결제  ...
#
#    SLE_ENTRPS_NM  RSVCTM_SEXDSTN_CODE  RSVCTM_AGRDE_CODE  RSVCTM_RSVCTM_VALUE  \
# 0          해비치CC                    1               50.0                  비도민
# 1          아덴힐GC                    1               50.0                  비도민
# 2          아덴힐GC                    1               50.0                   도민
#
#    RSVCTM_RVRG_VALUE RSVCTM_GOLF_CAREER_VALUE RSVCTM_AVRG_USE_VALUE  \
# ...

# %%
df_merge3.to_csv('골프장오리지널데이터.csv',index=False)

# %%
# df_merge3.isna().sum()
# df_merge3.info()

# %% [markdown]
# ## 인덱스 설정

# %%
golf_col_list = '골프장명 골프장지역명 대중제,회원제 18 사용일자 사용시간 성별코드 나이 도민,비도민 실력 골프경력 평균사용값 사용성향'.split()
or_golf_df3.columns = or_golf_df1.columns
# or_golf_df_phone.rename(columns={'TALKDTTM':'USE_DTTM'},inplace=True)
# or_golf_df_phone.rename(columns={'TALKTIME':'USGTM_VALUE'},inplace=True)
columnslist = or_golf_df_phone.columns

# %%
golf_df1=or_golf_df1[columnslist]
golf_df1['SLE_ENTRPS_NM']=or_golf_df1['SLE_ENTRPS_NM']
golf_df2=or_golf_df2[columnslist]
golf_df2['SLE_ENTRPS_NM']=or_golf_df2['SLE_ENTRPS_NM']
golf_df3=or_golf_df3[columnslist]
golf_df3['SLE_ENTRPS_NM']=or_golf_df3['SLE_ENTRPS_NM']
# Out:
# C:\Users\alsdn\AppData\Local\Temp/ipykernel_5816/1183616095.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   golf_df1['SLE_ENTRPS_NM']=or_golf_df1['SLE_ENTRPS_NM']
# C:\Users\alsdn\AppData\Local\Temp/ipykernel_5816/1183616095.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   golf_df2['SLE_ENTRPS_NM']=or_golf_df2['SLE_ENTRPS_NM']
# C:\Users\alsdn\AppData\Local\Temp/ipykernel_5816/1183616095.py:6: SettingWithCopyWarning:
# ...

# %%
or_golf_df_phone.columns =golf_col_list

# %%
golf_df_phone = or_golf_df_phone.copy()
golf_df_phone.columns =golf_col_list

# %%
golf_df_phone['판매업체명'] = '통화'

# %%
golf_df_phone
# Out:
#           골프장명 골프장지역명 대중제,회원제  18      사용일자    사용시간  성별코드    나이 도민,비도민   실력  \
# 0         중문GC   서귀포권     대중제  18  20210531   83537     1  40.0     도민  144
# 1       더클래식CC    동부권     대중제  18  20210706  133106     2  40.0     도민  NaN
# 2       더클래식CC    동부권     대중제  18  20210706  134812     2  40.0     도민  NaN
# 3         제주CC   제주시권     대중제  18  20210706  134846     2  40.0     도민  NaN
# 4      스프링데일CC    동부권     대중제  18  20210706  135804     1  40.0     도민  NaN
# ...        ...    ...     ...  ..       ...     ...   ...   ...    ...  ...
# 18791     제주CC   제주시권     대중제  18  20210615  103439     1  40.0     도민   40
# 18792   더클래식CC    동부권     대중제  18  20210615  104114     2   NaN     도민  NaN
# 18793   더클래식CC    동부권     대중제  18  20210615  104132     2   NaN     도민  NaN
# 18794   더클래식CC    동부권     대중제  18  20210615  104224     2   NaN     도민  NaN
# 18795     제주CC   제주시권     대중제  18  20210615  104250     2   NaN     도민  NaN
#
#        골프경력 평균사용값   사용성향 판매업체명
# ...

# %%
golf_df1.columns = golf_df_phone.columns
golf_df2.columns = golf_df_phone.columns
golf_df3.columns = golf_df_phone.columns

# %%
df_list = [golf_df_phone,golf_df1,golf_df2,golf_df3]
or_golf_df_concat = pd.concat([golf_df_phone,golf_df1,golf_df2,golf_df3],axis=0)

# %%
or_golf_df_concat.to_csv('골프장데이터합친거.csv',index=False)

# %%
golf_df=or_golf_df_concat.copy()

# %%
del golf_df['실력']

# %%
golf_df
# Out:
#          골프장명 골프장지역명  대중제,회원제  18      사용일자    사용시간  성별코드    나이 도민,비도민  골프경력  \
# 0        중문GC   서귀포권      대중제  18  20210531   83537     1  40.0     도민   NaN
# 1      더클래식CC    동부권      대중제  18  20210706  133106     2  40.0     도민   NaN
# 2      더클래식CC    동부권      대중제  18  20210706  134812     2  40.0     도민  1~3년
# 3        제주CC   제주시권      대중제  18  20210706  134846     2  40.0     도민  1~3년
# 4     스프링데일CC    동부권      대중제  18  20210706  135804     1  40.0     도민   NaN
# ...       ...    ...      ...  ..       ...     ...   ...   ...    ...   ...
# 4469    해비치CC    동부권  회원제+대중제  36  20201231    1227     0   NaN     도민   NaN
# 4470     라온GC    서부권      대중제  27  20201226    1132     0   NaN     도민   NaN
# 4471   더클래식CC    동부권      대중제  18  20210127     743     2   NaN     도민  4~6년
# 4472    아덴힐GC    서부권      대중제  18  20201228    1215     2  40.0     도민   NaN
# 4473   더클래식CC    동부권      대중제  18  20210119     756     1  40.0     도민  1~3년
#
#      평균사용값  사용성향  판매업체명
# ...

# %%
golf_df.사용성향.value_counts()
# Out:
# 주중골프                                                    3872
# 골프초년생                                                   3716
# 주말골프                                                    2903
# 번개골프                                                     634
# 새벽골프                                                     579
#                                                         ...
# 내기파,오후골프,뒷풀이,음주가무                                          1
# 주말골프,번개골프,제주여행                                             1
# 골프초년생,주말골프,오후골프                                            1
# 주중골프,주말골프,번개골프,제주여행                                        1
# 골프초년생,실력파,내기파,주중골프,주말골프,번개골프,새벽골프,오후골프,뒷풀이,음주가무,제주여행       1
# Name: 사용성향, Length: 272, dtype: int64

# %%
golf_df.성별코드.value_counts()
# Out:
# 1    23991
# 0    13016
# 2     8319
# Name: 성별코드, dtype: int64

# %%
golf_df.isnull().sum()
# Out:
# 골프장명           0
# 골프장지역명         0
# 대중제,회원제        0
# 18             0
# 사용일자           0
# 사용시간           0
# 성별코드           0
# 나이         15228
# 도민,비도민         0
# 골프경력       25557
# 평균사용값      25561
# 사용성향       26709
# 판매업체명          0
# dtype: int64

# %%
golf_df_concat_dropnull = golf_df_concat.dropna(axis=0)

# %%
golf_df_concat_dropnull
# Out:
#                골프장명 골프장지역명  대중제,회원제  18      통화일자    통화시간  성별코드    나이 도민,비도민  \
# 7              제주CC  제주시내권      대중제  18  20211102  160934     1  30.0     도민
# 9           스프링데일CC    동부권      대중제  18  20211102  161145     1  30.0     도민
# 10           더클래식CC    동부권      대중제  18  20211102  161233     1  30.0     도민
# 12   그린필드CC(구 제피로스)  제주시내권      회원제  18  20211102  161327     1  30.0     도민
# 15          스프링데일CC    동부권      대중제  18  20211102  161443     1  30.0     도민
# 23             제주CC  제주시내권      대중제  18  20211102  164147     1  50.0     도민
# 24          스프링데일CC    동부권      대중제  18  20211102  164402     1  50.0     도민
# 41           에버리스CC    서부권      회원제  27  20211102  174938     2  40.0    비도민
# 53   그린필드CC(구 제피로스)  제주시내권      회원제  18  20211102   90808     1  20.0     도민
# 54            한라산CC  제주시내권      대중제  18  20211102   90859     1  20.0     도민
# 71          스프링데일CC    동부권      대중제  18  20211102   91500     1  20.0     도민
# ...

# %%
golf_df_concat_dropnull.reset_index(drop=True,inplace=True)

# %%
golf_df_concat_dropnull

# %%
df = pd.read_csv('C:\workspace\\Next_Ez_Training\data\golflike\골프장오리지널데이터.csv')
# Out:
# C:\src\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (6,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# ### 인덱스 한글로 바꾸기

# %%
column_nmae_kr_phone = '''
골프장명
골프장지역명
골프장멤버십값
골프장유형값
사용일자
사용시간값
사용유형명
거주자금액
비거주자금액
결제수단명
총인원수
거주자인원수
비거주자인원수
예약일자
예약시간
판매업체명
예약자성별코드
예약자연령대코드
예약자거주지값
예약자평균값
예약자골프경력값
예약자평균사용값
예약자사용성향값
통화일자
통화시간
'''

# %%
column_nmae_kr = '''
골프장명
골프장지역명
골프장멤버십값
골프장유형값
사용일자
사용시간값
사용유형명
거주자금액
비거주자금액
결제수단명
총인원수
거주자인원수
비거주자인원수
예약일자
예약시간
판매업체명
예약자성별코드
예약자연령대코드
예약자거주지값
예약자평균값
예약자골프경력값
예약자평균사용값
예약자사용성향값
'''

# %%
column_nmae_kr=column_nmae_kr.split('\n')

# %%
column_name_kr= column_nmae_kr[1:-1]

# %%
len(column_name_kr)
# Out:
# 23

# %%
df=pd.read_csv('2203최신값.csv')

# %%
df.head(3)
# Out:
#   GLCRS_NM GLCRS_AREA_NM GLCRS_MBRSH_VALUE  GLCRS_TY_VALUE  USE_DTTM  \
# 0    해비치CC           동부권           회원제+대중제              36  20210120
# 1    아덴힐GC           서부권               대중제              18  20210121
# 2    아덴힐GC           서부권               대중제              18  20210126
#
#    USGTM_VALUE USETY_NM  RESIDNT_AMOUNT  UNRESID_AMOUNT SETLE_MN_NM  ...  \
# 0          815      SKY          170000          170000        현장결제  ...
# 1          809      왕이메           90000          135000        현장결제  ...
# 2          823      왕이메           90000          135000        현장결제  ...
#
#    RESVE_DTTM  RESVE_TIME  SLE_ENTRPS_NM  RSVCTM_SEXDSTN_CODE  \
# 0    20210114       93902          해비치CC                    1
# 1    20210114       94001          아덴힐GC                    1
# 2    20210114       95020          아덴힐GC                    1
#
#    RSVCTM_AGRDE_CODE RSVCTM_RSVCTM_VALUE RSVCTM_RVRG_VALUE  \
# 0               50.0                 비도민                 8
# ...

# %%
len(df.columns)
# Out:
# 23

# %%
df.columns=column_name_kr

# %%
df
# Out:
#         골프장명 골프장지역명  골프장멤버십값  골프장유형값      사용일자  사용시간값 사용유형명   거주자금액  비거주자금액  \
# 0      해비치CC    동부권  회원제+대중제      36  20210120    815   SKY  170000  170000
# 1      아덴힐GC    서부권      대중제      18  20210121    809   왕이메   90000  135000
# 2      아덴힐GC    서부권      대중제      18  20210126    823   왕이메   90000  135000
# 3      아덴힐GC    서부권      대중제      18  20210128    809   왕이메   90000  135000
# 4      아덴힐GC    서부권      대중제      18  20210208   1121    새별  110000  145000
# ...      ...    ...      ...     ...       ...    ...   ...     ...     ...
# 30913  아덴힐GC    서부권      대중제      18  20220324   1210    새별  155000  190000
# 30914  아덴힐GC    서부권      대중제      18  20220307   1203   왕이메  130000  190000
# 30915   라온GC    서부권      대중제      27  20220304   1146  LAKE  142500  202500
# 30916  아덴힐GC    서부권      대중제      18  20220316   1128    새별  155000  190000
# 30917  아덴힐GC    서부권      대중제      18  20220310    721    새별  130000  190000
#
# ...

# %%
# df.to_csv('골프장예약데이터ver0302.csv',index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30918 entries, 0 to 30917
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   골프장명      30918 non-null  object
#  1   골프장지역명    30918 non-null  object
#  2   골프장멤버십값   30918 non-null  object
#  3   골프장유형값    30918 non-null  int64
#  4   사용일자      30918 non-null  int64
#  5   사용시간값     30918 non-null  int64
#  6   사용유형명     30918 non-null  object
#  7   거주자금액     30918 non-null  int64
#  8   비거주자금액    30918 non-null  int64
#  9   결제수단명     30918 non-null  object
#  10  총인원수      30918 non-null  int64
#  11  거주자인원수    30918 non-null  int64
#  12  비거주자인원수   30918 non-null  int64
#  13  예약일자      30918 non-null  int64
#  14  예약시간      30918 non-null  int64
#  15  판매업체명     30918 non-null  object
#  16  예약자성별코드   30918 non-null  object
#  17  예약자연령대코드  21563 non-null  object
#  18  예약자거주지값   30918 non-null  object
#  19  예약자평균값    17330 non-null  object
# ...

# %%
# df.to_csv('골프장오리지널데이터_컬럼한글화2.csv',index=False)
