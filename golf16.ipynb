# %% [markdown]
# # 넥스트 이지 골프장 데이터를 이용한 데이터 분석 시각화

# %%
# !pip install pandas-profiling 
# ! conda install -c anaconda pandas-profiling

# %%
# !pip install https://github.com/pandas-profiling/pandas-profiling/archive/master.zip
# Out:
# ...
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# ...
#   Created wheel for pandas-profiling: filename=pandas_profiling-3.1.1-py2.py3-none-any.whl size=261291 sha256=cded5feb531607d3a73eadffac5c3735e0a33959270260622e778c7c542a761d
#   Stored in directory: C:\Users\alsdn\AppData\Local\Temp\pip-ephem-wheel-cache-pdhdi2xn\wheels\43\c8\f4\c0ebc32d7f20fe89d0e92d90eaeef5f0c0594a89b6bc16b352
# Successfully built pandas-profiling
# ...
#   Attempting uninstall: tangled-up-in-unicode
#     Found existing installation: tangled-up-in-unicode 0.1.0
#     Uninstalling tangled-up-in-unicode-0.1.0:
#       Successfully uninstalled tangled-up-in-unicode-0.1.0
#   Attempting uninstall: visions
#     Found existing installation: visions 0.4.4
#     Uninstalling visions-0.4.4:
#       Successfully uninstalled visions-0.4.4
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.0.1
#     Uninstalling joblib-1.0.1:
#       Successfully uninstalled joblib-1.0.1
# ...

# %%
# !pip install pydot
# !pip install pygraphviz
# Out:
# ...
#   Running setup.py clean for pygraphviz
# Failed to build pygraphviz
# ...
#     Running setup.py install for pygraphviz: started
#     Running setup.py install for pygraphviz: finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\alsdn\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\alsdn\\AppData\\Local\\Temp\\pip-install-14uv39_h\\pygraphviz_1f7027a6cf114e43b4afe0215473d4cb\\setup.py'"'"'; __file__='"'"'C:\\Users\\alsdn\\AppData\\Local\\Temp\\pip-install-14uv39_h\\pygraphviz_1f7027a6cf114e43b4afe0215473d4cb\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\alsdn\AppData\Local\Temp\pip-wheel-dhh4ncd3'
# ...

# %%
# !pip install pandas-profiling --trusted-host pypi.python.org --trusted-host files.pythonhosted.org --trusted-host pypi.org
# Out:
# ...
#   Using cached visions-0.4.4-py3-none-any.whl (59 kB)
# ...
#   Attempting uninstall: visions
#     Found existing installation: visions 0.5.0
#     Uninstalling visions-0.5.0:
#       Successfully uninstalled visions-0.5.0
# ...

# %%
# !pip install pandas-profiling==2.8.0 --user
# Out:
#   WARNING: The script pandas_profiling.exe is installed in 'C:\Users\alsdn\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
# !pip show pandas-profiling
# Out:
# Name: pandas-profiling
# Version: 3.1.0
# Summary: Generate profile report for pandas DataFrame
# Home-page: https://github.com/pandas-profiling/pandas-profiling
# Author: Simon Brugman
# Author-email: pandasprofiling@gmail.com
# License: MIT
# Location: c:\users\alsdn\anaconda3\lib\site-packages
# Requires: seaborn, matplotlib, numpy, joblib, phik, jinja2, scipy, multimethod, tangled-up-in-unicode, pydantic, pandas, PyYAML, markupsafe, requests, missingno, visions, tqdm, htmlmin
# Required-by:

# %% [markdown]
# ##  use lib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import copy
import matplotlib as mpl
import datetime
from datetime import timedelta
# from datetime import datetime, date
mpl.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.family'] = 'Malgun Gothic'
import os

# %% [markdown]
# ## use data

# %%
df = pd.read_csv('D:\WorkSpace\\Next_Ez_jejudo\data\\골프장데이터년도별\\합친거\\예약데이터_합친거(0314).csv')
df_cancel = pd.read_csv('D:\WorkSpace\\Next_Ez_jejudo\data\\골프장데이터년도별\\합친거\\예약취소데이터merge.csv')
df_call = pd.read_csv('D:\WorkSpace\\Next_Ez_jejudo\data\\골프장데이터년도별\\합친거\\예약데이터전화.csv')

# %% [markdown]
# ### 전화연결통계

# %%
plt.figure(figsize=(15,15))
df_call.groupby(df_call.call시간대).골프장지역명.count().plot.pie(fontsize=20,autopct='%.1f%%')
# Out:
# <AxesSubplot:ylabel='골프장지역명'>

# %% [markdown]
# ### 시각화통계

# %%
df.groupby([df['해당년도'],df['예약시간대별']]).예약시간대별.count().unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='해당년도'>

# %% [markdown]
# ### 사전예약대 통계

# %%
df.groupby([df['해당년도'],df['날짜차이요일']]).날짜차이요일.count().unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='해당년도'>

# %%
df_cancel.groupby([df_cancel['해당년도'],df_cancel['사전예약취소']]).사전예약취소.count().unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='해당년도'>

# %% [markdown]
# ### 예약시간대별 취소통계

# %%
df_cancel.groupby([df_cancel['해당년도'],df_cancel['예약시간대별']]).예약시간대별.count().unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='해당년도'>

# %% [markdown]
# ### 사전예약취소

# %%
df_cancel.groupby([df_cancel['해당년도'],df_cancel['사전예약취소']]).사전예약취소.count().unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='해당년도'>

# %% [markdown]
# ### 사용일통계

# %%
df.groupby([df['해당년도'],df['사용일통계']]).사용일통계.count().unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='해당년도'>

# %% [markdown]
# ### 가격대별 예약 통계

# %%
df.groupby([df['해당년도'],df['거주자금액나눔']]).거주자금액나눔.count().unstack().plot.bar()
# Out:
# <AxesSubplot:xlabel='해당년도'>

# %%
df[df.비거주자금액!=0].groupby([df['해당년도'],df['비거주자나눔']]).비거주자나눔.count().unstack().plot.bar()
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1940/194546475.py in <module>
# ----> 1 df[df.비거주자금액!=0].groupby([df['해당년도'],df['비거주자나눔']]).비거주자나눔.count().unstack().plot.bar()
#       2 plt.grid()
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## 사전예약 취소 가격대별 통계

# %%
df_cancel[df_cancel.비거주자금액!=0].groupby([df_cancel['해당년도'],df_cancel['비거주자나눔']]).비거주자나눔.count().unstack().plot.bar()

# %%
df_cancel.groupby([df_cancel['해당년도'],df_cancel['거주자금액나눔']]).거주자금액나눔.count().unstack().plot.bar()

# %%
df
# Out:
#          골프장명 골프장지역명  골프장멤버십값  골프장유형값      사용일자  사용시간값 사용유형명   거주자금액  비거주자금액  \
# 0       아덴힐GC    서부권      대중제      18  20220309    852    새별  155000  220000
# 1        라온GC    서부권      대중제      27  20220315   1235  LAKE  152500  182500
# 2      그린필드CC  제주시내권      회원제      18  20220314    756     M  132000  132000
# 3        라온GC    서부권      대중제      27  20220315   1228  LAKE  152500  182500
# 4      그린필드CC  제주시내권      회원제      18  20220314    749     M  132000  132000
# ...       ...    ...      ...     ...       ...    ...   ...     ...     ...
# 22851    제주CC   제주시권      대중제      18  20211030   1233    랜덤  165000  165000
# 22852    제주CC   제주시권      대중제      18  20211102    717    랜덤  135000  135000
# 22853   해비치CC    동부권  회원제+대중제      36  20211030   1248  PALM  200000  260000
# 22854   해비치CC    동부권  회원제+대중제      36  20211101    712  LAKE  150000  190000
# 22855   해비치CC    동부권  회원제+대중제      36  20211106    712  LAKE  190000  230000
#
# ...

# %%
import pandas as pd
import pandas_profiling

# %%
profile = ProfileReport(df, title='골프장데이터')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1940/1746935598.py in <module>
# ----> 1 profile = ProfileReport(df, title='골프장데이터')
#
# NameError: name 'ProfileReport' is not defined

# %%
profile.to_file(output_file='test.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1940/1778886218.py in <module>
# ----> 1 profile.to_file(output_file='test.html')
#
# NameError: name 'profile' is not defined

# %%
import pandas as pd
import numpy as np 
import pandas_profiling

def main():
    print("Start")

    # df = pd.DataFrame(
    #     np.random.rand(100, 5), 
    #     columns = ['a', 'b', 'c', 'd', 'e']
    # )
    print(df.head())

    # dataframe을 리포트로 만들어주고, 
    profile = df.profile_report()
    # 리포트를 html로 추출합니다. 
    profile.to_file(output_file="output.html")
    
main()
# Out:
# Start
#      골프장명 골프장지역명 골프장멤버십값  골프장유형값      사용일자  사용시간값 사용유형명   거주자금액  비거주자금액 결제수단명  \
# 0   아덴힐GC    서부권     대중제      18  20220309    852    새별  155000  220000  현장결제
# 1    라온GC    서부권     대중제      27  20220315   1235  LAKE  152500  182500  현장결제
# 2  그린필드CC  제주시내권     회원제      18  20220314    756     M  132000  132000   선결제
# 3    라온GC    서부권     대중제      27  20220315   1228  LAKE  152500  182500  현장결제
# 4  그린필드CC  제주시내권     회원제      18  20220314    749     M  132000  132000   선결제
#
#    ...   해당년도             거주자금액나눔              비거주자나눔       예약년월일       사용년월일  \
# 0  ...  2022년  140,000 ~ 160,000원         200,000원 이상  2022-03-01  2022-03-09
# 1  ...  2022년  140,000 ~ 160,000원  180,000 ~ 200,000원  2022-03-01  2022-03-15
# 2  ...  2022년  130,000 ~ 140,000원  130,000 ~ 140,000원  2022-03-01  2022-03-14
# 3  ...  2022년  140,000 ~ 160,000원  180,000 ~ 200,000원  2022-03-01  2022-03-15
# 4  ...  2022년  130,000 ~ 140,000원  130,000 ~ 140,000원  2022-03-01  2022-03-14
#
# ...

# %%
import numpy as np
import pandas as pd
import pandas_profiling as pp
# df = pd.read_csv('/content/sample_data/california_housing_train.csv')
profile = pp.ProfileReport(df,lazy=False)
profile
# Out:
# Summarize dataset:  15%|█▍        | 7/47 [00:00<00:01, 30.24it/s, Describe variable:총인원수]
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17972/3128086719.py in <module>
#       3 import pandas_profiling as pp
#       4 # df = pd.read_csv('/content/sample_data/california_housing_train.csv')
# ----> 5 profile = pp.ProfileReport(df,lazy=False)
#       6 profile
#
# ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py in __init__(self, df, minimal, explorative, config_file, lazy, **kwargs)
#      83             raise ValueError(
#      84                 "Arguments `config_file` and `minimal` are mutually exclusive."
# ---> 85             )
#      86
#      87         if config_file or minimal:
#
# ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py in report(self)
#     160         if self._description_set is None:
# ...

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df['Survived'] = df['Survived'].astype(bool)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1     False       3
# 1            2      True       1
# 2            3      True       3
# 3            4      True       1
# 4            5     False       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas_profiling as pp
report = pp.ProfileReport(df, lazy=False)
report
# Out:
# Summarize dataset:  15%|█▌        | 4/26 [00:00<00:00, 54.77it/s, Describe variable:Sex]
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17972/368439351.py in <module>
#       1 import pandas_profiling as pp
# ----> 2 report = pp.ProfileReport(df, lazy=False)
#       3 report
#
# ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py in __init__(self, df, minimal, explorative, config_file, lazy, **kwargs)
#      83             raise ValueError(
#      84                 "Arguments `config_file` and `minimal` are mutually exclusive."
# ---> 85             )
#      86
#      87         if config_file or minimal:
#
# ~\anaconda3\lib\site-packages\pandas_profiling\profile_report.py in report(self)
#     160         if self._description_set is None:
#     161             self._description_set = describe_df(
# ...
